# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_old = pd.read_csv('/home/rmfarizky/Project/deteksi_stunting/Dataset/Draft/dataset.csv')
df_old.shape
# Out:
# (624, 11)

# %%
df_old.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 624 entries, 0 to 623
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  624 non-null    int64
#  1   JK          624 non-null    int64
#  2   usia ukur   624 non-null    int64
#  3   Berat       624 non-null    float64
#  4   Tinggi      624 non-null    float64
#  5   ZS BB/U     624 non-null    float64
#  6   ZS TB/U     624 non-null    float64
#  7   ZS BB/TB    624 non-null    float64
#  8   BB/U        624 non-null    object
#  9   TB/U        624 non-null    object
#  10  BB/TB       624 non-null    object
# dtypes: float64(5), int64(3), object(3)
# memory usage: 53.8+ KB

# %%
df_old.rename(columns={'usia ukur': 'Usia Saat Ukur'}, 
        inplace=True)

# %%
df_new = pd.read_excel('/home/rmfarizky/Project/deteksi_stunting/Dataset/Draft/new_data.xlsx')
df_new.shape
# Out:
# (602, 32)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 602 entries, 0 to 601
# Data columns (total 32 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   NIK                 602 non-null    object
#  1   Nama                602 non-null    object
#  2   JK                  602 non-null    object
#  3   Tgl Lahir           602 non-null    object
#  4   BB Lahir            602 non-null    object
#  5   TB Lahir            602 non-null    object
#  6   Nama Ortu           602 non-null    object
#  7   Prov                602 non-null    object
#  8   Kab/Kota            602 non-null    object
#  9   Kec                 602 non-null    object
#  10  Pukesmas            602 non-null    object
#  11  Desa/Kel            602 non-null    object
#  12  Posyandu            602 non-null    object
#  13  RT                  602 non-null    object
#  14  RW                  602 non-null    object
# ...

# %%
df_new['BB/U'][df_new['BB/U'] == 'Berat Badan Normal'] = 'Normal'
# Out:
# /tmp/ipykernel_4976/1240916913.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['BB/U'][df_new['BB/U'] == 'Berat Badan Normal'] = 'Normal'

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 12))


df_new['BB/U'].value_counts().plot.bar(color='maroon', ax=axs[0,0])
axs[0,0].set_title('BB/U Distribution')

df_new['TB/U'].value_counts().plot.bar(color='maroon', ax=axs[0,1])
axs[0,1].set_title('TB/U Distribution')

df_new['BB/TB'].value_counts().plot.bar(color='maroon', ax=axs[0,2])
axs[0,2].set_title('TB/U Distribution')

df_old['BB/U'].value_counts().plot.bar(color='maroon', ax=axs[1,0])
axs[1,0].set_title('BB/U Distribution')

df_old['TB/U'].value_counts().plot.bar(color='maroon', ax=axs[1,1])
axs[1,1].set_title('TB/U Distribution')

df_old['BB/TB'].value_counts().plot.bar(color='maroon', ax=axs[1,2])
axs[1,2].set_title('TB/U Distribution')

fig.text(0.5, 0.92, 'Data Baru', ha='center', va='center', fontsize=14)
fig.text(0.5, 0.45, 'Data Lama', ha='center', va='center', fontsize=14)
plt.subplots_adjust(hspace=0.7, wspace=0.2)

plt.show()

# %%
df_new2 = df_new
df_new2
# Out:
#                     NIK                    Nama   JK    Tgl Lahir BB Lahir  \
# 0    5208032802220007     A. FEBRIAN AL FARIZI   0.0  2022-02-28        3
# 1        520803100321               Abdul Azim   1.0  2021-03-10        3
# 2    5208032303190001             Abdul Rahman   1.0  2019-03-23        2
# 3    5208031405210007          Abizar Al-Ayubi   0.0  2021-05-14        3
# 4        520803170720                    AIRIN   1.0  2020-07-07        3
# ..                  ...                     ...  ...          ...      ...
# 597  5208032909230009         M. KHAERUL AZZAM   NaN  2023-09-29      3.7
# 598  5208036608230001      HANA JANNATUL MAKWA   NaN  2023-08-26      2.6
# 599  5208037008230001          SULIS SETIAWATI   NaN  2023-08-30      3.2
# 600  5208031809230001    NABDA ABYAN BIMANTARA   NaN  2023-09-18      2.6
# 601  5208032108230011      AHMAD KHAIRUL SAKIR   NaN  2023-08-21      2.3
#
# ...

# %%
COL_FEATURE = ['JK','Usia Saat Ukur','Berat','Tinggi','ZS BB/U','ZS TB/U',	'ZS BB/TB',	'BB/U',	'TB/U',	'BB/TB']

# %%
df_combined = pd.concat([df_old[df_old['TB/U'] == 'Tinggi'], 
                         df_old[df_old['BB/TB'] == 'Gizi Buruk'], 
                         df_old[df_old['BB/TB'] == 'Obesitas'],  
                         df_old[df_old['BB/TB'] == 'Gizi Kurang'],
                         df_old[df_old['BB/TB'] == 'Gizi Lebih']
                         ], ignore_index=True)
df_combined = df_combined.drop(columns='Unnamed: 0')

df_combined['Usia Saat Ukur'] = df_combined['Usia Saat Ukur'].apply(lambda x: f"{x // 12} Tahun - {x % 12} Bulan - 0 Hari")
df_combined
# Out:
#     JK               Usia Saat Ukur  Berat  Tinggi  ZS BB/U  ZS TB/U  \
# 0    0   4 Tahun - 8 Bulan - 0 Hari   14.3   101.0     1.52     3.05
# 1    1   1 Tahun - 3 Bulan - 0 Hari    9.2    74.0    -3.60    -2.58
# 2    1   5 Tahun - 0 Bulan - 0 Hari   12.3   100.0    -3.90    -2.88
# 3    0  0 Tahun - 10 Bulan - 0 Hari    9.0    74.0    -2.52    -0.79
# 4    1   4 Tahun - 1 Bulan - 0 Hari   13.3    97.0    -3.66    -2.99
# ..  ..                          ...    ...     ...      ...      ...
# 70   1   1 Tahun - 7 Bulan - 0 Hari    9.7    73.0     0.69    -1.71
# 71   1   0 Tahun - 8 Bulan - 0 Hari    8.4    70.0    -0.49    -3.96
# 72   1   3 Tahun - 8 Bulan - 0 Hari   12.4    94.0    -0.40    -3.51
# 73   1  3 Tahun - 10 Bulan - 0 Hari   14.5    95.0     0.96    -1.35
# 74   0  0 Tahun - 11 Bulan - 0 Hari    8.5    70.5     1.19    -0.59
#
#     ZS BB/TB           BB/U           TB/U       BB/TB
# 0       0.22   Risiko Lebih         Tinggi   Gizi Baik
# ...

# %%
df_combined.to_excel('selected.xlsx', index= False )
