# %%
import numpy as np
import pandas as pd
from PIL import Image

# %%
df_stun = pd.read_excel(
    '/home/rmfarizky/Project/deteksi_stunting/Prepros1.xlsx',
    )

print('Data downloaded and read into a dataframe!')
# Out:
# Data downloaded and read into a dataframe!

# %%
df_stun.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 624 entries, 0 to 623
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   nama_anak  624 non-null    object
#  1   tgl_lahir  624 non-null    object
#  2   tgl_ukur   624 non-null    datetime64[ns]
#  3   berat      624 non-null    float64
#  4   tinggi     624 non-null    object
#  5   lila       589 non-null    float64
#  6   ket        0 non-null      float64
# dtypes: datetime64[ns](1), float64(3), object(3)
# memory usage: 34.3+ KB

# %%
df_stun["tgl_lahir"] = pd.to_datetime(df_stun["tgl_lahir"])

# %%
df_stun['usia_ukur'] = df_stun['tgl_ukur'] - df_stun['tgl_lahir']

# %%
df_stun['usia_ukur']
# Out:
# 0     1757 days
# 1     1724 days
# 2     1693 days
# 3     1666 days
# 4     1620 days
#          ...
# 619    279 days
# 620    272 days
# 621    221 days
# 622    219 days
# 623     65 days
# Name: usia_ukur, Length: 624, dtype: timedelta64[ns]

# %%
def days_to_months(td):
    return td.days / 30.4375 

df_stun['usia_ukur(bulan)'] = df_stun['usia_ukur'].apply(days_to_months)

# %%
df_stun['usia_ukur(bulan)']
# Out:
# 0      57.724846
# 1      56.640657
# 2      55.622177
# 3      54.735113
# 4      53.223819
#          ...
# 619     9.166324
# 620     8.936345
# 621     7.260780
# 622     7.195072
# 623     2.135524
# Name: usia_ukur(bulan), Length: 624, dtype: float64

# %%
df_stun['usia_ukur(bulan)'] = df_stun['usia_ukur(bulan)'].round().astype(int)

# %%
df_stun.drop(columns='lila')
# Out:
#               nama_anak  tgl_lahir   tgl_ukur  berat tinggi  ket usia_ukur  \
# 0         Arlan Saputra 2018-04-03 2023-01-24   13.1   97.5  NaN 1757 days
# 1          Anggun Laili 2018-05-06 2023-01-24   12.2   98.5  NaN 1724 days
# 2          Sivaul Qolbi 2018-06-06 2023-01-24   12.6   95.5  NaN 1693 days
# 3                  Rael 2018-07-03 2023-01-24   14.2   99.3  NaN 1666 days
# 4         SILVIA ANJANI 2018-08-18 2023-01-24   13.2     97  NaN 1620 days
# ..                  ...        ...        ...    ...    ...  ...       ...
# 619       SAFA ANGGIANA 2022-04-07 2023-01-11    7.0   67.5  NaN  279 days
# 620                ZOYA 2022-04-14 2023-01-11    7.6   67.5  NaN  272 days
# 621   TRESNO ADI DHARMA 2022-06-04 2023-01-11    6.5     65  NaN  221 days
# 622  ERIN CANTIKA PUTRI 2022-06-06 2023-01-11    6.1   65.5  NaN  219 days
# 623   Najwa Ima Syuhada 2022-11-07 2023-01-11    5.6     60  NaN   65 days
#
#      usia_ukur(bulan)
# 0                  58
# ...

# %%
df_stun.to_excel('Prepros2.xlsx', index=False)

# %%
# Hitung jumlah total baris
total_rows = len(df_stun)

# Hitung jumlah 'L' (Laki-laki) dan 'P' (Perempuan) dengan proporsi yang diinginkan
total_laki_laki = int(total_rows * 0.47)  # Misalnya, 40% Laki-laki
total_perempuan = total_rows - total_laki_laki

# Buat array dengan nilai 'L' dan 'P' yang sesuai dengan proporsi
jenis_kelamin = np.array(['L'] * total_laki_laki + ['P'] * total_perempuan)

# Acak urutan elemen dalam array
np.random.shuffle(jenis_kelamin)

# %%
jenis_kelamin
# Out:
# array(['P', 'P', 'P', 'L', 'L', 'L', 'P', 'L', 'L', 'P', 'L', 'L', 'L',
#        'L', 'P', 'P', 'P', 'L', 'P', 'P', 'L', 'L', 'P', 'P', 'P', 'L',
#        'P', 'P', 'L', 'L', 'L', 'P', 'P', 'P', 'L', 'P', 'P', 'P', 'L',
#        'L', 'P', 'P', 'P', 'P', 'L', 'P', 'L', 'L', 'P', 'P', 'P', 'L',
#        'P', 'L', 'P', 'P', 'P', 'P', 'L', 'P', 'P', 'L', 'L', 'L', 'P',
#        'P', 'P', 'L', 'L', 'L', 'P', 'P', 'P', 'L', 'P', 'P', 'P', 'L',
#        'P', 'P', 'L', 'P', 'P', 'P', 'P', 'P', 'L', 'P', 'L', 'P', 'L',
#        'L', 'P', 'L', 'P', 'P', 'L', 'L', 'P', 'L', 'L', 'P', 'L', 'P',
#        'P', 'P', 'L', 'P', 'P', 'P', 'L', 'L', 'L', 'P', 'L', 'L', 'L',
#        'P', 'P', 'L', 'P', 'P', 'P', 'P', 'L', 'P', 'L', 'L', 'L', 'P',
#        'P', 'L', 'L', 'P', 'L', 'P', 'P', 'L', 'P', 'P', 'L', 'L', 'L',
#        'L', 'P', 'L', 'P', 'L', 'L', 'L', 'P', 'P', 'L', 'P', 'L', 'P',
#        'P', 'P', 'L', 'P', 'L', 'L', 'L', 'L', 'L', 'L', 'P', 'P', 'P',
# ...

# %%
df_stun['j_kel'] = jenis_kelamin

# %%
df_stun.drop(columns='nama_anak', inplace=True)

# %%
df_stun.drop(columns='lila', inplace=True)

# %%
df_stun
# Out:
#      tgl_lahir   tgl_ukur  berat tinggi  ket usia_ukur  usia_ukur(bulan) j_kel
# 0   2018-04-03 2023-01-24   13.1   97.5  NaN 1757 days                58     P
# 1   2018-05-06 2023-01-24   12.2   98.5  NaN 1724 days                57     P
# 2   2018-06-06 2023-01-24   12.6   95.5  NaN 1693 days                56     P
# 3   2018-07-03 2023-01-24   14.2   99.3  NaN 1666 days                55     L
# 4   2018-08-18 2023-01-24   13.2     97  NaN 1620 days                53     L
# ..         ...        ...    ...    ...  ...       ...               ...   ...
# 619 2022-04-07 2023-01-11    7.0   67.5  NaN  279 days                 9     P
# 620 2022-04-14 2023-01-11    7.6   67.5  NaN  272 days                 9     L
# 621 2022-06-04 2023-01-11    6.5     65  NaN  221 days                 7     P
# 622 2022-06-06 2023-01-11    6.1   65.5  NaN  219 days                 7     L
# 623 2022-11-07 2023-01-11    5.6     60  NaN   65 days                 2     L
#
# [624 rows x 8 columns]

# %%
df_stun.to_excel('Prepros3.xlsx', index=False)

# %%
df_stun = df_stun[['j_kel', 'tgl_lahir', 'tgl_ukur','usia_ukur(bulan)', 'berat','tinggi']]

# %%
df_stun['tgl_lahir'] = df_stun['tgl_lahir'].dt.date
df_stun['tgl_ukur'] = df_stun['tgl_ukur'].dt.date
# Out:
# /tmp/ipykernel_214/84521829.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_stun['tgl_lahir'] = df_stun['tgl_lahir'].dt.date
# /tmp/ipykernel_214/84521829.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_stun['tgl_ukur'] = df_stun['tgl_ukur'].dt.date

# %%
df_stun.to_excel('Prepros3.xlsx', index=False)

# %% [markdown]
# ## Prepros4

# %%
df_stun =  pd.read_excel(
    '/home/rmfarizky/Project/deteksi_stunting/Prepros3.xlsx',
    )

print('Data downloaded and read into a dataframe!')
# Out:
# Data downloaded and read into a dataframe!

# %%
df_stun.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 624 entries, 0 to 623
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   j_kel             624 non-null    object
#  1   tgl_lahir         624 non-null    datetime64[ns]
#  2   tgl_ukur          624 non-null    datetime64[ns]
#  3   usia_ukur(bulan)  624 non-null    int64
#  4   berat             624 non-null    float64
#  5   tinggi            624 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 29.4+ KB

# %%
df_stun
# Out:
#     j_kel  tgl_lahir   tgl_ukur  usia_ukur(bulan)  berat tinggi
# 0       P 2018-04-03 2023-01-24                58   13.1   97.5
# 1       P 2018-05-06 2023-01-24                57   12.2   98.5
# 2       P 2018-06-06 2023-01-24                56   12.6   95.5
# 3       L 2018-07-03 2023-01-24                55   14.2   99.3
# 4       L 2018-08-18 2023-01-24                53   13.2     97
# ..    ...        ...        ...               ...    ...    ...
# 619     P 2022-04-07 2023-01-11                 9    7.0   67.5
# 620     L 2022-04-14 2023-01-11                 9    7.6   67.5
# 621     P 2022-06-04 2023-01-11                 7    6.5     65
# 622     L 2022-06-06 2023-01-11                 7    6.1   65.5
# 623     L 2022-11-07 2023-01-11                 2    5.6     60
#
# [624 rows x 6 columns]

# %%
df_stun['tinggi'] = df_stun['tinggi'].apply(lambda x: x.replace(',', '.') if isinstance(x, str) else x).astype(float)

# %%
df_stun =  pd.read_excel(
    '/home/rmfarizky/Project/deteksi_stunting/dataset.xlsx',
    )

print('Data downloaded and read into a dataframe!')
# Out:
# Data downloaded and read into a dataframe!

# %%
df_stun
# Out:
#      tgl_lahir      j_kel  usia_ukur(bulan)  berat  tinggi   tgl_ukur  \
# 0   2018-04-03  Laki-laki                58   13.1    97.5 2023-01-24
# 1   2018-05-06  Perempuan                57   12.2    98.5 2023-01-24
# 2   2018-06-06  Perempuan                56   12.6    95.5 2023-01-24
# 3   2018-07-03  Laki-laki                55   14.2    99.3 2023-01-24
# 4   2018-08-18  Perempuan                53   13.2    97.0 2023-01-24
# ..         ...        ...               ...    ...     ...        ...
# 619 2022-04-07  Perempuan                 9    7.0    67.5 2023-01-11
# 620 2022-04-14  Laki-laki                 9    7.6    67.5 2023-01-11
# 621 2022-06-04  Perempuan                 7    6.5    65.0 2023-01-11
# 622 2022-06-06  Perempuan                 7    6.1    65.5 2023-01-11
# 623 2022-11-07  Perempuan                 2    5.6    60.0 2023-01-11
#
#      Z_BB/TB  Z_BB/U  Z_TB/U  Z_IMT/U        BB/TB    BB/U    TB/U  \
# ...
